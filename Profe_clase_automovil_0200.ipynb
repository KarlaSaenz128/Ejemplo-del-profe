# %% [markdown]
# <a href="https://colab.research.google.com/github/KarlaSaenz128/Ejemplo-del-profe/blob/main/Profe_clase_automovil_0200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Karla Saenz 0133 NL = 48 GPO 2H
# #### clase automovil con 3 atributos funciones leerdatos(),mostrados()
# #### que sea interactivo --> los imput
# #### crear 3 objetos carro1,carro2,carro3
# ### no usar while true,if,for,listas y diccionarios

# %%
class Automovil:
    def __init__(self,MARCA,PLACA,PRECIO):
        # Initialize attributes, leetaros will get interactive input later
        self.marca = ""
        self.placas = ""
        self.precio = ""

    def leetaros(self):
        # Correctly assign to instance attributes (lowercase)
        self.marca = input("Ingrese la marca del automovil: ")
        self.placas = input("Ingrese la placa de automovil: ")
        self.precio = input("Ingrese el precio de automovil: ")
        # No return needed as it modifies the object's state

    def mostrados(self):
        print("Marca:", self.marca)
        print("Placas:", self.placas)
        print("Precio:", self.precio)

        # fin de la clase automovil

        print("-*-*-*-*")
    # Mostrando datos para cada carro

print("---Datos del carro 1 ---")
carro1 = Automovil("","","")
carro1.mostrados()
carro1.leetaros()
print("-*-*-*-*")
print("--- Datos del carro 2")
carro2 = Automovil("","","")
carro2.mostrados()
carro2.leetaros()
print("-*-*-*-*")
print("--- Datos del carro 3")
carro3 = Automovil("","","")
carro3.mostrados()
carro3.leetaros()
print("-*-*-*-*")
print("ELABORADO por karla saenz0133")
# Out:
# ---Datos del carro 1 ---
# Marca:
# Placas:
# Precio:
# -*-*-*-*
# Ingrese la marca del automovil: honda
# Ingrese la placa de automovil: 270JJKD
# Ingrese el precio de automovil: 240000
# -*-*-*-*
# --- Datos del carro 2
# Marca:
# Placas:
# Precio:
# -*-*-*-*
# Ingrese la marca del automovil: FERRARI
# Ingrese la placa de automovil: 1280KSN
# Ingrese el precio de automovil: 270000
# -*-*-*-*
# --- Datos del carro 3
# Marca:
# Placas:
# Precio:
# -*-*-*-*
# Ingrese la marca del automovil: TOYOTA
# Ingrese la placa de automovil: 234TTSNS
# Ingrese el precio de automovil: 23000
# -*-*-*-*
# ELABORADO por karla saenz0133

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/KarlaSaenz128/Ejemplo-del-profe/refs/heads/main/abril29.png)
